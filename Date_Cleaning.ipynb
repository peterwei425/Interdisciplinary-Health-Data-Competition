# %% [markdown]
# # Interdisciplinary Health Data Competition - Data Cleaning

# %% [markdown]
# ## Import necessary libraries

# %%
import pandas as pd
import numpy as np
import warnings

# %% [markdown]
# ## Agenda

# %% [markdown]
# Step 1 - Read in Data Files
# - Read in drug and prescription files
# - Inspect their initial format
# - Inspect their initial data types
# - Inspect data distribution
#
# Step 2 - Check for Nulls
# - Check for nulls by count
# - Check for nulls by percentage
# - Replace any known nulls
# - Drop columns with ~20% or more missing values
# - Drop rows with ~10% or less missing values
#
# Step 3 - Try to Impute Nulls in Percent Change
# - analyze head of dataframe
# - analyze the cost per script rank
# - remove original percent change features
#
# Step 4 - Properly Join the Two Files
# - join prescription 2012 to prescription 2016
# - create new percent change features
# - fill in calculations for the percent change columns in prescription
# - join drug 2012 to drug 2016
#
# Step 5 - Create Lists Where Applicable
#
# Step 6 - Write cleaned data to new files

# %% [markdown]
# ## Step 1 - Read in Data Files

# %%
# read in the first file and inspect
drug = pd.read_excel("DrugDetailMerged.xlsx")
drug.head()
# Out:
#    YEAR RECORD_TYPE  NUMBER_SCRIPTS       NDC9 PRODUCT_NDC  LAUNCH_YEAR  \
# 0  2012         NDC              61  449461023  44946-1023       2011.0
# 1  2012         NDC              52  449461024  44946-1024       2011.0
# 2  2012         NDC              24  449461025  44946-1025       2011.0
# 3  2012         NDC              25  449461024  44946-1024       2011.0
# 4  2012         NDC              36  758540301   75854-301       2012.0
#
#                                            NPROPNAME  \
# 0  .ALPHA.,TOCOPHEROL ACETATE, DL,, ASCORBIC ACID...
# 1  .ALPHA.,TOCOPHEROL ACETATE, DL,, ASCORBIC ACID...
# 2  .ALPHA.,TOCOPHEROL ACETATE, DL,, ASCORBIC ACID...
# 3  .ALPHA.,TOCOPHEROL ACETATE, DL,, ASCORBIC ACID...
# 4  .BETA.,CAROTENE, ASCORBIC ACID, CHOLECALCIFERO...
#
#                      PROPNAME GENERIC_DRUG_IND_CODE            THER_CLASS  \
# 0  MULTIVITAMIN WITH FLUORIDE               Generic  Nutritional Products
# 1  MULTIVITAMIN WITH FLUORIDE               Generic  Nutritional Products
# 2  MULTIVITAMIN WITH FLUORIDE               Generic  Nutritional Products
# 3  MULTIVITAMIN WITH FLUORIDE               Generic  Nutritional Products
# 4               PRENATE ELITE                 Brand  Nutritional Products
#
#         ...       INSURER_PAID_STDDEV INSURER_PAID_SUM MEMBER_PAID_MEDIAN  \
# 0       ...                  6.773281           321.68              15.23
# 1       ...                  6.621973           160.28              10.18
# 2       ...                  6.543839           109.56              10.00
# 3       ...                  2.962455           218.90               0.00
# 4       ...                 81.140106          4127.63              40.61
#
#   MEMBER_PAID_MEAN MEMBER_PAID_STDDEV  MEMBER_PAID_SUM  TOTAL_PAID_MEDIAN  \
# 0        12.211967           7.758228           744.93              17.44
# 1        11.648654           9.022594           605.73              14.96
# 2        11.942917           5.914719           286.63              17.32
# 3         0.000000           0.000000             0.00               7.37
# 4        63.982222          79.410866          2303.36             153.85
#
#    TOTAL_PAID_MEAN  TOTAL_PAID_STDDEV  TOTAL_PAID_SUM
# 0        17.485410           6.349664         1066.61
# 1        14.730962           9.387626          766.01
# 2        16.507917           5.275046          396.19
# 3         8.761600           2.959877          219.04
# 4       178.638611         106.344757         6430.99
#
# [5 rows x 40 columns]

# %%
# inspect data types
drug.dtypes
# Out:
# YEAR                         int64
# RECORD_TYPE                 object
# NUMBER_SCRIPTS               int64
# NDC9                         int64
# PRODUCT_NDC                 object
# LAUNCH_YEAR                float64
# NPROPNAME                   object
# PROPNAME                    object
# GENERIC_DRUG_IND_CODE       object
# THER_CLASS                  object
# LABELERNAME                 object
# DOSAGE_FORM                 object
# ACTIVE_STRENGTH             object
# ACTIVE_STRENGTH_UNIT        object
# PAYER                       object
# UNIQUE_MEMBERS               int64
# TOTAL_COST                 float64
# COST_PER_USER              float64
# COST_PER_SCRIPT            float64
# COST_PER_DAYS_SUPPLY       float64
# COST_PER_UNIT_DISPENSED    float64
# TOTAL_SCRIPTS_FILLED         int64
# DAYS_SUPPLY_MEDIAN         float64
# DAYS_SUPPLY_MEAN           float64
# DAYS_SUPPLY_STDDEV         float64
# QUANTITY_MEDIAN            float64
# QUANTITY_MEAN              float64
# QUANTITY_STDDEV            float64
# INSURER_PAID_MEDIAN        float64
# INSURER_PAID_MEAN          float64
# INSURER_PAID_STDDEV        float64
# INSURER_PAID_SUM           float64
# MEMBER_PAID_MEDIAN         float64
# MEMBER_PAID_MEAN           float64
# MEMBER_PAID_STDDEV         float64
# MEMBER_PAID_SUM            float64
# TOTAL_PAID_MEDIAN          float64
# TOTAL_PAID_MEAN            float64
# TOTAL_PAID_STDDEV          float64
# TOTAL_PAID_SUM             float64
# dtype: object

# %%
# Inspect data distribution
drug.describe()
# Out:
#                YEAR  NUMBER_SCRIPTS          NDC9   LAUNCH_YEAR  \
# count  58299.000000    58299.000000  5.829900e+04  51822.000000
# mean    2014.117704     1907.544160  2.925065e+08   2006.495330
# std        1.996551     6389.540882  2.825932e+08      8.628465
# min     2012.000000       11.000000  0.000000e+00   1900.000000
# 25%     2012.000000       71.000000  3.952838e+06   2004.000000
# 50%     2016.000000      248.000000  2.315505e+08   2009.000000
# 75%     2016.000000     1118.500000  5.789605e+08   2011.000000
# max     2016.000000   222810.000000  9.920705e+08   2019.000000
#
#        UNIQUE_MEMBERS    TOTAL_COST  COST_PER_USER  COST_PER_SCRIPT  \
# count    58299.000000  5.829900e+04   58299.000000     58299.000000
# mean       761.104822  1.710579e+05     797.708650       208.245714
# std       2783.494766  1.315084e+06    5054.301835      1131.587113
# min         11.000000  2.890000e+00       0.180625         0.180625
# 25%         30.000000  2.207805e+03      24.401119        10.773499
# 50%         98.000000  1.204032e+04      70.288785        29.999088
# 75%        435.000000  5.769987e+04     257.863950       103.254048
# max     122975.000000  1.450619e+08  375453.225000     73004.793750
#
#        COST_PER_DAYS_SUPPLY  COST_PER_UNIT_DISPENSED       ...        \
# count          58299.000000             58299.000000       ...
# mean               7.390627                17.368790       ...
# std               51.156846               231.158146       ...
# min                0.008600                 0.001492       ...
# 25%                0.356612                 0.182733       ...
# 50%                0.983575                 0.529266       ...
# 75%                3.490333                 2.229693       ...
# max             7007.324345             17589.369406       ...
#
#        INSURER_PAID_STDDEV  INSURER_PAID_SUM  MEMBER_PAID_MEDIAN  \
# count         58299.000000      5.829900e+04        58299.000000
# mean            121.661856      1.454995e+05            7.939869
# std             625.345322      1.206305e+06           25.826820
# min               0.000000      0.000000e+00            0.000000
# 25%               7.366863      1.560860e+03            0.000000
# 50%              23.313743      8.773700e+03            1.910000
# 75%              71.973515      4.246544e+04           10.000000
# max           51937.267544      1.367770e+08         1783.840000
#
#        MEMBER_PAID_MEAN  MEMBER_PAID_STDDEV  MEMBER_PAID_SUM  \
# count      58299.000000        58299.000000     5.829900e+04
# mean          16.366089           27.944861     2.438385e+04
# std           47.488616           96.090746     1.447407e+05
# min            0.000000            0.000000     0.000000e+00
# 25%            0.996496            1.907238     1.800100e+02
# 50%            5.221292            7.078508     1.408240e+03
# 75%           15.259937           21.156922     8.706125e+03
# max         2833.294687         4975.867439     9.728195e+06
#
#        TOTAL_PAID_MEDIAN  TOTAL_PAID_MEAN  TOTAL_PAID_STDDEV  TOTAL_PAID_SUM
# count       58299.000000     58299.000000       58299.000000    5.829900e+04
# mean          179.519354       208.245714         123.413276    1.710579e+05
# std          1027.125319      1131.587113         626.286942    1.315084e+06
# min             0.190000         0.180625           0.000000    2.890000e+00
# 25%             8.120000        10.773499           8.205806    2.207805e+03
# 50%            22.460000        29.999088          24.652300    1.204032e+04
# 75%            81.370000       103.254048          74.584304    5.769987e+04
# max         54247.490000     73004.793750       52087.073348    1.450619e+08
#
# [8 rows x 29 columns]

# %%
# read in the first file and inspect
prescription = pd.read_excel("SummaryMerged.xlsx")
prescription.head()
# Out:
#    YEAR RECORD_TYPE  NUMBER_SCRIPTS  \
# 0  2012        Drug             137
# 1  2012        Drug              25
# 2  2012        Drug              36
# 3  2012        Drug             210
# 4  2012        Drug             117
#
#                                            NPROPNAME            THER_CLASS  \
# 0  .ALPHA.,TOCOPHEROL ACETATE, DL,, ASCORBIC ACID...  Nutritional Products
# 1  .ALPHA.,TOCOPHEROL ACETATE, DL,, ASCORBIC ACID...  Nutritional Products
# 2  .BETA.,CAROTENE, ASCORBIC ACID, CHOLECALCIFERO...  Nutritional Products
# 3  .BETA.,CAROTENE, ASCORBIC ACID, CHOLECALCIFERO...  Nutritional Products
# 4  .BETA.,CAROTENE, ASCORBIC ACID, CHOLECALCIFERO...  Nutritional Products
#
#                             PAYER  UNIQUE_MEMBERS  TOTAL_COST  COST_PER_USER  \
# 0                      Commercial              99     2228.81      22.513232
# 1  Minnesota Health Care Programs              13      219.04      16.849231
# 2                      Commercial              26     6430.99     247.345769
# 3                      Commercial              92     3810.43      41.417717
# 4  Minnesota Health Care Programs              56     1082.49      19.330179
#
#    COST_PER_SCRIPT         ...           PCT_SCRIPTS_0_18  PCT_SCRIPTS_19_44  \
# 0        16.268686         ...                      100.0                0.0
# 1         8.761600         ...                        NaN                NaN
# 2       178.638611         ...                        0.0              100.0
# 3        18.144905         ...                        NaN                NaN
# 4         9.252051         ...                        NaN                NaN
#
#    PCT_SCRIPTS_45_64  PCT_SCRIPTS_65_PLUS  PCT_SCRIPTS_FEMALE  \
# 0                0.0                  0.0           48.905109
# 1                NaN                  NaN                 NaN
# 2                0.0                  0.0          100.000000
# 3                NaN                  NaN          100.000000
# 4                NaN                  NaN                 NaN
#
#    PCT_SCRIPTS_MALE  PCT_URBAN_CORE  PCT_SUBURBAN  PCT_MICROPOLITAN  \
# 0         51.094891       20.437956     21.167883         45.255474
# 1               NaN             NaN           NaN               NaN
# 2          0.000000             NaN           NaN               NaN
# 3          0.000000             NaN           NaN               NaN
# 4               NaN             NaN           NaN               NaN
#
#    PCT_RURAL_SMALLTOWN
# 0            13.138686
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 50 columns]

# %%
# inspect data types
prescription.dtypes
# Out:
# YEAR                                 int64
# RECORD_TYPE                         object
# NUMBER_SCRIPTS                       int64
# NPROPNAME                           object
# THER_CLASS                          object
# PAYER                               object
# UNIQUE_MEMBERS                       int64
# TOTAL_COST                         float64
# COST_PER_USER                      float64
# COST_PER_SCRIPT                    float64
# COST_PER_DAYS_SUPPLY               float64
# COST_PER_UNIT_DISPENSED            float64
# TOTAL_SCRIPTS_FILLED                 int64
# PCT_CHANGE_COST_PER_SCRIPT         float64
# TOTAL_COST_RANK                      int64
# COST_PER_USER_RANK                   int64
# COST_PER_SCRIPT_RANK                 int64
# COST_PER_DAYS_SUPPLY_RANK            int64
# COST_PER_UNIT_DISPENSED_RANK         int64
# TOTAL_SCRIPTS_FILLED_RANK            int64
# PCT_CHANGE_COST_PER_SCRIPT_RANK    float64
# DAYS_SUPPLY_MEDIAN                 float64
# DAYS_SUPPLY_MEAN                   float64
# DAYS_SUPPLY_STDDEV                 float64
# QUANTITY_MEDIAN                    float64
# QUANTITY_MEAN                      float64
# QUANTITY_STDDEV                    float64
# INSURER_PAID_MEDIAN                float64
# INSURER_PAID_MEAN                  float64
# INSURER_PAID_STDDEV                float64
# INSURER_PAID_SUM                   float64
# MEMBER_PAID_MEDIAN                 float64
# MEMBER_PAID_MEAN                   float64
# MEMBER_PAID_STDDEV                 float64
# MEMBER_PAID_SUM                    float64
# TOTAL_PAID_MEDIAN                  float64
# TOTAL_PAID_MEAN                    float64
# TOTAL_PAID_STDDEV                  float64
# TOTAL_PAID_SUM                     float64
# PCT_TOTAL_PHARM_SPENDING           float64
# PCT_SCRIPTS_0_18                   float64
# PCT_SCRIPTS_19_44                  float64
# PCT_SCRIPTS_45_64                  float64
# PCT_SCRIPTS_65_PLUS                float64
# PCT_SCRIPTS_FEMALE                 float64
# PCT_SCRIPTS_MALE                   float64
# PCT_URBAN_CORE                     float64
# PCT_SUBURBAN                       float64
# PCT_MICROPOLITAN                   float64
# PCT_RURAL_SMALLTOWN                float64
# dtype: object

# %%
# Inspect data distribution
prescription.describe()
# Out:
#               YEAR  NUMBER_SCRIPTS  UNIQUE_MEMBERS    TOTAL_COST  \
# count  8455.000000     8455.000000     8455.000000  8.455000e+03
# mean   2014.019160    13152.917445     4308.200591  1.179480e+06
# std       2.000026    46422.933559    15403.472815  4.776704e+06
# min    2012.000000       11.000000       11.000000  2.998000e+01
# 25%    2012.000000      136.000000       51.000000  8.977245e+03
# 50%    2016.000000      803.000000      272.000000  7.927720e+04
# 75%    2016.000000     5487.500000     1871.500000  5.507450e+05
# max    2016.000000   790872.000000   381363.000000  1.775626e+08
#
#        COST_PER_USER  COST_PER_SCRIPT  COST_PER_DAYS_SUPPLY  \
# count    8455.000000      8455.000000           8455.000000
# mean     2578.153297       569.442394             21.229498
# std     10931.001135      2447.865128            121.156683
# min         1.177277         1.104720              0.027031
# 25%        39.691584        16.907883              0.621009
# 50%       145.470675        55.666024              2.058153
# 75%       718.516435       224.981117              8.330387
# max    238221.929375     57317.515000           7007.324345
#
#        COST_PER_UNIT_DISPENSED  TOTAL_SCRIPTS_FILLED  \
# count              8455.000000           8455.000000
# mean                 51.895639          13152.917445
# std                 427.740200          46422.933559
# min                   0.002460             11.000000
# 25%                   0.269303            136.000000
# 50%                   1.144981            803.000000
# 75%                   6.779317           5487.500000
# max               15867.378285         790872.000000
#
#        PCT_CHANGE_COST_PER_SCRIPT         ...           PCT_SCRIPTS_0_18  \
# count                 7004.000000         ...                5210.000000
# mean                    45.063242         ...                   9.209697
# std                    305.890815         ...                  18.814400
# min                    -99.662323         ...                   0.000000
# 25%                    -27.329524         ...                   0.000000
# 50%                      0.207009         ...                   0.529011
# 75%                     52.000604         ...                   8.646617
# max                   7613.114958         ...                 100.000000
#
#        PCT_SCRIPTS_19_44  PCT_SCRIPTS_45_64  PCT_SCRIPTS_65_PLUS  \
# count        5210.000000        5210.000000          5210.000000
# mean           23.696248          36.997350            30.096706
# std            20.574852          23.320994            34.092183
# min             0.000000           0.000000             0.000000
# 25%             6.238080          16.189259             2.658529
# 50%            20.563030          38.206872            12.519637
# 75%            36.000743          55.049245            59.614436
# max           100.000000         100.000000           100.000000
#
#        PCT_SCRIPTS_FEMALE  PCT_SCRIPTS_MALE  PCT_URBAN_CORE  PCT_SUBURBAN  \
# count         7724.000000       7724.000000     6028.000000   6028.000000
# mean            59.289551         40.710449       60.939713      9.934860
# std             18.204456         18.204456       12.747692      3.903336
# min              0.000000          0.000000        0.000000      0.000000
# 25%             49.217004         30.825780       54.024815      7.770706
# 50%             59.286234         40.713766       61.341711      9.803353
# 75%             69.174220         50.782996       68.702872     11.902961
# max            100.000000        100.000000      100.000000     39.333333
#
#        PCT_MICROPOLITAN  PCT_RURAL_SMALLTOWN
# count       6028.000000          6028.000000
# mean          11.746726            17.378701
# std            5.173913             8.409159
# min            0.000000             0.000000
# 25%            8.695734            11.764706
# 50%           11.411118            16.307281
# 75%           14.204316            21.686767
# max           60.937500            81.699346
#
# [8 rows x 46 columns]

# %% [markdown]
# ## Step 2 - Check for Nulls

# %%
# count of nulls
drug.isnull().sum()
# Out:
# YEAR                          0
# RECORD_TYPE                   0
# NUMBER_SCRIPTS                0
# NDC9                          0
# PRODUCT_NDC                6477
# LAUNCH_YEAR                6477
# NPROPNAME                     0
# PROPNAME                    185
# GENERIC_DRUG_IND_CODE         0
# THER_CLASS                    0
# LABELERNAME                6024
# DOSAGE_FORM                3178
# ACTIVE_STRENGTH            4460
# ACTIVE_STRENGTH_UNIT       4472
# PAYER                         0
# UNIQUE_MEMBERS                0
# TOTAL_COST                    0
# COST_PER_USER                 0
# COST_PER_SCRIPT               0
# COST_PER_DAYS_SUPPLY          0
# COST_PER_UNIT_DISPENSED       0
# TOTAL_SCRIPTS_FILLED          0
# DAYS_SUPPLY_MEDIAN            0
# DAYS_SUPPLY_MEAN              0
# DAYS_SUPPLY_STDDEV            0
# QUANTITY_MEDIAN               0
# QUANTITY_MEAN                 0
# QUANTITY_STDDEV               0
# INSURER_PAID_MEDIAN           0
# INSURER_PAID_MEAN             0
# INSURER_PAID_STDDEV           0
# INSURER_PAID_SUM              0
# MEMBER_PAID_MEDIAN            0
# MEMBER_PAID_MEAN              0
# MEMBER_PAID_STDDEV            0
# MEMBER_PAID_SUM               0
# TOTAL_PAID_MEDIAN             0
# TOTAL_PAID_MEAN               0
# TOTAL_PAID_STDDEV             0
# TOTAL_PAID_SUM                0
# dtype: int64

# %%
# Percentage of null values for easier analysis
drug.isnull().sum()* 100 / len(drug)
# Out:
# YEAR                        0.000000
# RECORD_TYPE                 0.000000
# NUMBER_SCRIPTS              0.000000
# NDC9                        0.000000
# PRODUCT_NDC                11.109968
# LAUNCH_YEAR                11.109968
# NPROPNAME                   0.000000
# PROPNAME                    0.317330
# GENERIC_DRUG_IND_CODE       0.000000
# THER_CLASS                  0.000000
# LABELERNAME                10.332939
# DOSAGE_FORM                 5.451208
# ACTIVE_STRENGTH             7.650217
# ACTIVE_STRENGTH_UNIT        7.670801
# PAYER                       0.000000
# UNIQUE_MEMBERS              0.000000
# TOTAL_COST                  0.000000
# COST_PER_USER               0.000000
# COST_PER_SCRIPT             0.000000
# COST_PER_DAYS_SUPPLY        0.000000
# COST_PER_UNIT_DISPENSED     0.000000
# TOTAL_SCRIPTS_FILLED        0.000000
# DAYS_SUPPLY_MEDIAN          0.000000
# DAYS_SUPPLY_MEAN            0.000000
# DAYS_SUPPLY_STDDEV          0.000000
# QUANTITY_MEDIAN             0.000000
# QUANTITY_MEAN               0.000000
# QUANTITY_STDDEV             0.000000
# INSURER_PAID_MEDIAN         0.000000
# INSURER_PAID_MEAN           0.000000
# INSURER_PAID_STDDEV         0.000000
# INSURER_PAID_SUM            0.000000
# MEMBER_PAID_MEDIAN          0.000000
# MEMBER_PAID_MEAN            0.000000
# MEMBER_PAID_STDDEV          0.000000
# MEMBER_PAID_SUM             0.000000
# TOTAL_PAID_MEDIAN           0.000000
# TOTAL_PAID_MEAN             0.000000
# TOTAL_PAID_STDDEV           0.000000
# TOTAL_PAID_SUM              0.000000
# dtype: float64

# %%
# count of nulls
prescription.isnull().sum()
# Out:
# YEAR                                  0
# RECORD_TYPE                           0
# NUMBER_SCRIPTS                        0
# NPROPNAME                             0
# THER_CLASS                            0
# PAYER                                 0
# UNIQUE_MEMBERS                        0
# TOTAL_COST                            0
# COST_PER_USER                         0
# COST_PER_SCRIPT                       0
# COST_PER_DAYS_SUPPLY                  0
# COST_PER_UNIT_DISPENSED               0
# TOTAL_SCRIPTS_FILLED                  0
# PCT_CHANGE_COST_PER_SCRIPT         1451
# TOTAL_COST_RANK                       0
# COST_PER_USER_RANK                    0
# COST_PER_SCRIPT_RANK                  0
# COST_PER_DAYS_SUPPLY_RANK             0
# COST_PER_UNIT_DISPENSED_RANK          0
# TOTAL_SCRIPTS_FILLED_RANK             0
# PCT_CHANGE_COST_PER_SCRIPT_RANK    1451
# DAYS_SUPPLY_MEDIAN                    0
# DAYS_SUPPLY_MEAN                      0
# DAYS_SUPPLY_STDDEV                    0
# QUANTITY_MEDIAN                       0
# QUANTITY_MEAN                         0
# QUANTITY_STDDEV                       0
# INSURER_PAID_MEDIAN                   0
# INSURER_PAID_MEAN                     0
# INSURER_PAID_STDDEV                   0
# INSURER_PAID_SUM                      0
# MEMBER_PAID_MEDIAN                    0
# MEMBER_PAID_MEAN                      0
# MEMBER_PAID_STDDEV                    0
# MEMBER_PAID_SUM                       0
# TOTAL_PAID_MEDIAN                     0
# TOTAL_PAID_MEAN                       0
# TOTAL_PAID_STDDEV                     0
# TOTAL_PAID_SUM                        0
# PCT_TOTAL_PHARM_SPENDING              0
# PCT_SCRIPTS_0_18                   3245
# PCT_SCRIPTS_19_44                  3245
# PCT_SCRIPTS_45_64                  3245
# PCT_SCRIPTS_65_PLUS                3245
# PCT_SCRIPTS_FEMALE                  731
# PCT_SCRIPTS_MALE                    731
# PCT_URBAN_CORE                     2427
# PCT_SUBURBAN                       2427
# PCT_MICROPOLITAN                   2427
# PCT_RURAL_SMALLTOWN                2427
# dtype: int64

# %%
# Percentage of null values for easier analysis
prescription.isnull().sum()* 100 / len(prescription)
# Out:
# YEAR                                0.000000
# RECORD_TYPE                         0.000000
# NUMBER_SCRIPTS                      0.000000
# NPROPNAME                           0.000000
# THER_CLASS                          0.000000
# PAYER                               0.000000
# UNIQUE_MEMBERS                      0.000000
# TOTAL_COST                          0.000000
# COST_PER_USER                       0.000000
# COST_PER_SCRIPT                     0.000000
# COST_PER_DAYS_SUPPLY                0.000000
# COST_PER_UNIT_DISPENSED             0.000000
# TOTAL_SCRIPTS_FILLED                0.000000
# PCT_CHANGE_COST_PER_SCRIPT         17.161443
# TOTAL_COST_RANK                     0.000000
# COST_PER_USER_RANK                  0.000000
# COST_PER_SCRIPT_RANK                0.000000
# COST_PER_DAYS_SUPPLY_RANK           0.000000
# COST_PER_UNIT_DISPENSED_RANK        0.000000
# TOTAL_SCRIPTS_FILLED_RANK           0.000000
# PCT_CHANGE_COST_PER_SCRIPT_RANK    17.161443
# DAYS_SUPPLY_MEDIAN                  0.000000
# DAYS_SUPPLY_MEAN                    0.000000
# DAYS_SUPPLY_STDDEV                  0.000000
# QUANTITY_MEDIAN                     0.000000
# QUANTITY_MEAN                       0.000000
# QUANTITY_STDDEV                     0.000000
# INSURER_PAID_MEDIAN                 0.000000
# INSURER_PAID_MEAN                   0.000000
# INSURER_PAID_STDDEV                 0.000000
# INSURER_PAID_SUM                    0.000000
# MEMBER_PAID_MEDIAN                  0.000000
# MEMBER_PAID_MEAN                    0.000000
# MEMBER_PAID_STDDEV                  0.000000
# MEMBER_PAID_SUM                     0.000000
# TOTAL_PAID_MEDIAN                   0.000000
# TOTAL_PAID_MEAN                     0.000000
# TOTAL_PAID_STDDEV                   0.000000
# TOTAL_PAID_SUM                      0.000000
# PCT_TOTAL_PHARM_SPENDING            0.000000
# PCT_SCRIPTS_0_18                   38.379657
# PCT_SCRIPTS_19_44                  38.379657
# PCT_SCRIPTS_45_64                  38.379657
# PCT_SCRIPTS_65_PLUS                38.379657
# PCT_SCRIPTS_FEMALE                  8.645772
# PCT_SCRIPTS_MALE                    8.645772
# PCT_URBAN_CORE                     28.704908
# PCT_SUBURBAN                       28.704908
# PCT_MICROPOLITAN                   28.704908
# PCT_RURAL_SMALLTOWN                28.704908
# dtype: float64

# %%
# Replace any nulls with known values
# 'PROPNAME' NA means generic
drug['PROPNAME'] = drug['PROPNAME'].fillna('GENERIC')
drug.isnull().sum()* 100 / len(drug)
# Out:
# YEAR                        0.000000
# RECORD_TYPE                 0.000000
# NUMBER_SCRIPTS              0.000000
# NDC9                        0.000000
# PRODUCT_NDC                11.109968
# LAUNCH_YEAR                11.109968
# NPROPNAME                   0.000000
# PROPNAME                    0.000000
# GENERIC_DRUG_IND_CODE       0.000000
# THER_CLASS                  0.000000
# LABELERNAME                10.332939
# DOSAGE_FORM                 5.451208
# ACTIVE_STRENGTH             7.650217
# ACTIVE_STRENGTH_UNIT        7.670801
# PAYER                       0.000000
# UNIQUE_MEMBERS              0.000000
# TOTAL_COST                  0.000000
# COST_PER_USER               0.000000
# COST_PER_SCRIPT             0.000000
# COST_PER_DAYS_SUPPLY        0.000000
# COST_PER_UNIT_DISPENSED     0.000000
# TOTAL_SCRIPTS_FILLED        0.000000
# DAYS_SUPPLY_MEDIAN          0.000000
# DAYS_SUPPLY_MEAN            0.000000
# DAYS_SUPPLY_STDDEV          0.000000
# QUANTITY_MEDIAN             0.000000
# QUANTITY_MEAN               0.000000
# QUANTITY_STDDEV             0.000000
# INSURER_PAID_MEDIAN         0.000000
# INSURER_PAID_MEAN           0.000000
# INSURER_PAID_STDDEV         0.000000
# INSURER_PAID_SUM            0.000000
# MEMBER_PAID_MEDIAN          0.000000
# MEMBER_PAID_MEAN            0.000000
# MEMBER_PAID_STDDEV          0.000000
# MEMBER_PAID_SUM             0.000000
# TOTAL_PAID_MEDIAN           0.000000
# TOTAL_PAID_MEAN             0.000000
# TOTAL_PAID_STDDEV           0.000000
# TOTAL_PAID_SUM              0.000000
# dtype: float64

# %%
# Drop columns with ~20% of more missing values
#prescription = prescription.drop(['PCT_SCRIPTS_0_18','PCT_SCRIPTS_19_44', 'PCT_SCRIPTS_45_64',
#                                  'PCT_SCRIPTS_65_PLUS', 'PCT_URBAN_CORE', 'PCT_SUBURBAN',
#                                  'PCT_MICROPOLITAN', 'PCT_RURAL_SMALLTOWN'], axis = 1)

# %%
# Confirm columns were dropped
prescription.isnull().sum()* 100 / len(prescription)
# Out:
# YEAR                                0.000000
# RECORD_TYPE                         0.000000
# NUMBER_SCRIPTS                      0.000000
# NPROPNAME                           0.000000
# THER_CLASS                          0.000000
# PAYER                               0.000000
# UNIQUE_MEMBERS                      0.000000
# TOTAL_COST                          0.000000
# COST_PER_USER                       0.000000
# COST_PER_SCRIPT                     0.000000
# COST_PER_DAYS_SUPPLY                0.000000
# COST_PER_UNIT_DISPENSED             0.000000
# TOTAL_SCRIPTS_FILLED                0.000000
# PCT_CHANGE_COST_PER_SCRIPT         17.161443
# TOTAL_COST_RANK                     0.000000
# COST_PER_USER_RANK                  0.000000
# COST_PER_SCRIPT_RANK                0.000000
# COST_PER_DAYS_SUPPLY_RANK           0.000000
# COST_PER_UNIT_DISPENSED_RANK        0.000000
# TOTAL_SCRIPTS_FILLED_RANK           0.000000
# PCT_CHANGE_COST_PER_SCRIPT_RANK    17.161443
# DAYS_SUPPLY_MEDIAN                  0.000000
# DAYS_SUPPLY_MEAN                    0.000000
# DAYS_SUPPLY_STDDEV                  0.000000
# QUANTITY_MEDIAN                     0.000000
# QUANTITY_MEAN                       0.000000
# QUANTITY_STDDEV                     0.000000
# INSURER_PAID_MEDIAN                 0.000000
# INSURER_PAID_MEAN                   0.000000
# INSURER_PAID_STDDEV                 0.000000
# INSURER_PAID_SUM                    0.000000
# MEMBER_PAID_MEDIAN                  0.000000
# MEMBER_PAID_MEAN                    0.000000
# MEMBER_PAID_STDDEV                  0.000000
# MEMBER_PAID_SUM                     0.000000
# TOTAL_PAID_MEDIAN                   0.000000
# TOTAL_PAID_MEAN                     0.000000
# TOTAL_PAID_STDDEV                   0.000000
# TOTAL_PAID_SUM                      0.000000
# PCT_TOTAL_PHARM_SPENDING            0.000000
# PCT_SCRIPTS_0_18                   38.379657
# PCT_SCRIPTS_19_44                  38.379657
# PCT_SCRIPTS_45_64                  38.379657
# PCT_SCRIPTS_65_PLUS                38.379657
# PCT_SCRIPTS_FEMALE                  8.645772
# PCT_SCRIPTS_MALE                    8.645772
# PCT_URBAN_CORE                     28.704908
# PCT_SUBURBAN                       28.704908
# PCT_MICROPOLITAN                   28.704908
# PCT_RURAL_SMALLTOWN                28.704908
# dtype: float64

# %%
# Drop rows with ~10% or less missing values and confirm rows were dropped
#prescription = prescription.dropna(axis=0, subset=['PCT_SCRIPTS_FEMALE', 'PCT_SCRIPTS_MALE'])
#prescription.isnull().sum()* 100 / len(prescription)
# Out:
# YEAR                                0.000000
# RECORD_TYPE                         0.000000
# NUMBER_SCRIPTS                      0.000000
# NPROPNAME                           0.000000
# THER_CLASS                          0.000000
# PAYER                               0.000000
# UNIQUE_MEMBERS                      0.000000
# TOTAL_COST                          0.000000
# COST_PER_USER                       0.000000
# COST_PER_SCRIPT                     0.000000
# COST_PER_DAYS_SUPPLY                0.000000
# COST_PER_UNIT_DISPENSED             0.000000
# TOTAL_SCRIPTS_FILLED                0.000000
# PCT_CHANGE_COST_PER_SCRIPT         14.785085
# TOTAL_COST_RANK                     0.000000
# COST_PER_USER_RANK                  0.000000
# COST_PER_SCRIPT_RANK                0.000000
# COST_PER_DAYS_SUPPLY_RANK           0.000000
# COST_PER_UNIT_DISPENSED_RANK        0.000000
# TOTAL_SCRIPTS_FILLED_RANK           0.000000
# PCT_CHANGE_COST_PER_SCRIPT_RANK    14.785085
# DAYS_SUPPLY_MEDIAN                  0.000000
# DAYS_SUPPLY_MEAN                    0.000000
# DAYS_SUPPLY_STDDEV                  0.000000
# QUANTITY_MEDIAN                     0.000000
# QUANTITY_MEAN                       0.000000
# QUANTITY_STDDEV                     0.000000
# INSURER_PAID_MEDIAN                 0.000000
# INSURER_PAID_MEAN                   0.000000
# INSURER_PAID_STDDEV                 0.000000
# INSURER_PAID_SUM                    0.000000
# MEMBER_PAID_MEDIAN                  0.000000
# MEMBER_PAID_MEAN                    0.000000
# MEMBER_PAID_STDDEV                  0.000000
# MEMBER_PAID_SUM                     0.000000
# TOTAL_PAID_MEDIAN                   0.000000
# TOTAL_PAID_MEAN                     0.000000
# TOTAL_PAID_STDDEV                   0.000000
# TOTAL_PAID_SUM                      0.000000
# PCT_TOTAL_PHARM_SPENDING            0.000000
# PCT_SCRIPTS_FEMALE                  0.000000
# PCT_SCRIPTS_MALE                    0.000000
# dtype: float64

# %%
# Drop rows with ~10% or less missing values and confirm rows were dropped
drug = drug.dropna(axis=0, subset=['DOSAGE_FORM', 'ACTIVE_STRENGTH', 'ACTIVE_STRENGTH_UNIT', 'LABELERNAME', 'LAUNCH_YEAR', 'PRODUCT_NDC'])
drug.isnull().sum()* 100 / len(drug)
# Out:
# YEAR                       0.0
# RECORD_TYPE                0.0
# NUMBER_SCRIPTS             0.0
# NDC9                       0.0
# PRODUCT_NDC                0.0
# LAUNCH_YEAR                0.0
# NPROPNAME                  0.0
# PROPNAME                   0.0
# GENERIC_DRUG_IND_CODE      0.0
# THER_CLASS                 0.0
# LABELERNAME                0.0
# DOSAGE_FORM                0.0
# ACTIVE_STRENGTH            0.0
# ACTIVE_STRENGTH_UNIT       0.0
# PAYER                      0.0
# UNIQUE_MEMBERS             0.0
# TOTAL_COST                 0.0
# COST_PER_USER              0.0
# COST_PER_SCRIPT            0.0
# COST_PER_DAYS_SUPPLY       0.0
# COST_PER_UNIT_DISPENSED    0.0
# TOTAL_SCRIPTS_FILLED       0.0
# DAYS_SUPPLY_MEDIAN         0.0
# DAYS_SUPPLY_MEAN           0.0
# DAYS_SUPPLY_STDDEV         0.0
# QUANTITY_MEDIAN            0.0
# QUANTITY_MEAN              0.0
# QUANTITY_STDDEV            0.0
# INSURER_PAID_MEDIAN        0.0
# INSURER_PAID_MEAN          0.0
# INSURER_PAID_STDDEV        0.0
# INSURER_PAID_SUM           0.0
# MEMBER_PAID_MEDIAN         0.0
# MEMBER_PAID_MEAN           0.0
# MEMBER_PAID_STDDEV         0.0
# MEMBER_PAID_SUM            0.0
# TOTAL_PAID_MEDIAN          0.0
# TOTAL_PAID_MEAN            0.0
# TOTAL_PAID_STDDEV          0.0
# TOTAL_PAID_SUM             0.0
# dtype: float64

# %% [markdown]
# ## Step 3 - Try to Impute Nulls in Percent Change

# %%
# analyze head of dataframe
prescription.head()
# Out:
#    YEAR RECORD_TYPE  NUMBER_SCRIPTS  \
# 0  2012        Drug             137
# 1  2012        Drug              25
# 2  2012        Drug              36
# 3  2012        Drug             210
# 4  2012        Drug             117
#
#                                            NPROPNAME            THER_CLASS  \
# 0  .ALPHA.,TOCOPHEROL ACETATE, DL,, ASCORBIC ACID...  Nutritional Products
# 1  .ALPHA.,TOCOPHEROL ACETATE, DL,, ASCORBIC ACID...  Nutritional Products
# 2  .BETA.,CAROTENE, ASCORBIC ACID, CHOLECALCIFERO...  Nutritional Products
# 3  .BETA.,CAROTENE, ASCORBIC ACID, CHOLECALCIFERO...  Nutritional Products
# 4  .BETA.,CAROTENE, ASCORBIC ACID, CHOLECALCIFERO...  Nutritional Products
#
#                             PAYER  UNIQUE_MEMBERS  TOTAL_COST  COST_PER_USER  \
# 0                      Commercial              99     2228.81      22.513232
# 1  Minnesota Health Care Programs              13      219.04      16.849231
# 2                      Commercial              26     6430.99     247.345769
# 3                      Commercial              92     3810.43      41.417717
# 4  Minnesota Health Care Programs              56     1082.49      19.330179
#
#    COST_PER_SCRIPT         ...           PCT_SCRIPTS_0_18  PCT_SCRIPTS_19_44  \
# 0        16.268686         ...                      100.0                0.0
# 1         8.761600         ...                        NaN                NaN
# 2       178.638611         ...                        0.0              100.0
# 3        18.144905         ...                        NaN                NaN
# 4         9.252051         ...                        NaN                NaN
#
#    PCT_SCRIPTS_45_64  PCT_SCRIPTS_65_PLUS  PCT_SCRIPTS_FEMALE  \
# 0                0.0                  0.0           48.905109
# 1                NaN                  NaN                 NaN
# 2                0.0                  0.0          100.000000
# 3                NaN                  NaN          100.000000
# 4                NaN                  NaN                 NaN
#
#    PCT_SCRIPTS_MALE  PCT_URBAN_CORE  PCT_SUBURBAN  PCT_MICROPOLITAN  \
# 0         51.094891       20.437956     21.167883         45.255474
# 1               NaN             NaN           NaN               NaN
# 2          0.000000             NaN           NaN               NaN
# 3          0.000000             NaN           NaN               NaN
# 4               NaN             NaN           NaN               NaN
#
#    PCT_RURAL_SMALLTOWN
# 0            13.138686
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 50 columns]

# %%
# analyze cost per script rank

scriptRank = prescription[['YEAR','COST_PER_USER_RANK', 'COST_PER_SCRIPT_RANK', 'COST_PER_DAYS_SUPPLY_RANK',
                          'COST_PER_UNIT_DISPENSED_RANK', 'TOTAL_SCRIPTS_FILLED_RANK',
                          'PCT_CHANGE_COST_PER_SCRIPT_RANK']]
scriptRank.head()
# Out:
#    YEAR  COST_PER_USER_RANK  COST_PER_SCRIPT_RANK  COST_PER_DAYS_SUPPLY_RANK  \
# 0  2012                1319                  1241                       1416
# 1  2012                1156                  1149                       1199
# 2  2012                 644                   456                        703
# 3  2012                1151                  1215                       1362
# 4  2012                1117                  1130                       1155
#
#    COST_PER_UNIT_DISPENSED_RANK  TOTAL_SCRIPTS_FILLED_RANK  \
# 0                          1208                       1142
# 1                           926                       1257
# 2                           584                       1399
# 3                          1126                       1063
# 4                           895                        983
#
#    PCT_CHANGE_COST_PER_SCRIPT_RANK
# 0                            818.0
# 1                             59.0
# 2                              NaN
# 3                            164.0
# 4                            448.0

# %% [markdown]
# Appears the 'PCT_CHANGE_COST_PER_SCRIPT_RANK' and 'PCT_CHANGE_COST_PER_SCRIPT' are by year. Since I do not have the prior years (2011 and 2015), I cannot calculate the missing values.
#
# Instead I will make a new feature to compare the growth between 2012 and 2016. These will replace the 'PCT_CHANGE_COST_PER_SCRIPT_RANK' and 'PCT_CHANGE_COST_PER_SCRIPT' features. If the year is 2012, the percent change will be 0. If the year is 2016 I will calculate the percent change as follows:
#
# $PCT\_CHANGE\_COST\_PER\_SCRIPT\_RANK = \frac{(COST\_PER\_SCRIPT\_RANK\_2016 - COST\_PER\_SCRIPT\_RANK\_2012)}{COST\_PER\_SCRIPT\_RANK\_2012} \times 100\%$
#
# $PCT\_CHANGE\_COST\_PER\_SCRIPT = \frac{(COST\_PER\_SCRIPT\_2016 - COST\_PER\_SCRIPT\_2012)}{COST\_PER\_SCRIPT\_2012} \times 100\%$
#
# These formulas will be applied later.

# %%
# remove original percent change features and confirm removal
prescription = prescription.drop(['PCT_CHANGE_COST_PER_SCRIPT_RANK','PCT_CHANGE_COST_PER_SCRIPT'], axis = 1)
prescription.isnull().sum()* 100 / len(prescription)
# Out:
# YEAR                             0.000000
# RECORD_TYPE                      0.000000
# NUMBER_SCRIPTS                   0.000000
# NPROPNAME                        0.000000
# THER_CLASS                       0.000000
# PAYER                            0.000000
# UNIQUE_MEMBERS                   0.000000
# TOTAL_COST                       0.000000
# COST_PER_USER                    0.000000
# COST_PER_SCRIPT                  0.000000
# COST_PER_DAYS_SUPPLY             0.000000
# COST_PER_UNIT_DISPENSED          0.000000
# TOTAL_SCRIPTS_FILLED             0.000000
# TOTAL_COST_RANK                  0.000000
# COST_PER_USER_RANK               0.000000
# COST_PER_SCRIPT_RANK             0.000000
# COST_PER_DAYS_SUPPLY_RANK        0.000000
# COST_PER_UNIT_DISPENSED_RANK     0.000000
# TOTAL_SCRIPTS_FILLED_RANK        0.000000
# DAYS_SUPPLY_MEDIAN               0.000000
# DAYS_SUPPLY_MEAN                 0.000000
# DAYS_SUPPLY_STDDEV               0.000000
# QUANTITY_MEDIAN                  0.000000
# QUANTITY_MEAN                    0.000000
# QUANTITY_STDDEV                  0.000000
# INSURER_PAID_MEDIAN              0.000000
# INSURER_PAID_MEAN                0.000000
# INSURER_PAID_STDDEV              0.000000
# INSURER_PAID_SUM                 0.000000
# MEMBER_PAID_MEDIAN               0.000000
# MEMBER_PAID_MEAN                 0.000000
# MEMBER_PAID_STDDEV               0.000000
# MEMBER_PAID_SUM                  0.000000
# TOTAL_PAID_MEDIAN                0.000000
# TOTAL_PAID_MEAN                  0.000000
# TOTAL_PAID_STDDEV                0.000000
# TOTAL_PAID_SUM                   0.000000
# PCT_TOTAL_PHARM_SPENDING         0.000000
# PCT_SCRIPTS_0_18                38.379657
# PCT_SCRIPTS_19_44               38.379657
# PCT_SCRIPTS_45_64               38.379657
# PCT_SCRIPTS_65_PLUS             38.379657
# PCT_SCRIPTS_FEMALE               8.645772
# PCT_SCRIPTS_MALE                 8.645772
# PCT_URBAN_CORE                  28.704908
# PCT_SUBURBAN                    28.704908
# PCT_MICROPOLITAN                28.704908
# PCT_RURAL_SMALLTOWN             28.704908
# dtype: float64

# %% [markdown]
# ## Step 4 - Properly Join the Two Files

# %%
# divide the prescription file into their two years
prescription_2012 = prescription.loc[prescription['YEAR'] == 2012]
prescription_2012 = prescription_2012.add_suffix('_2012')
prescription_2016 = prescription.loc[prescription['YEAR'] == 2016]
prescription_2016 = prescription_2016.add_suffix('_2016')

# %%
# join prescription file on ['RECORD_TYPE','NPROPNAME', 'THER_CLASS','PAYER']
prescription_merged = prescription_2012.merge(prescription_2016, how = "outer", left_on = ['RECORD_TYPE_2012','NPROPNAME_2012', 'THER_CLASS_2012','PAYER_2012'],
                                             right_on = ['RECORD_TYPE_2016','NPROPNAME_2016', 'THER_CLASS_2016','PAYER_2016'])
prescription_merged.head()
# Out:
#    YEAR_2012 RECORD_TYPE_2012  NUMBER_SCRIPTS_2012  \
# 0     2012.0             Drug                137.0
# 1     2012.0             Drug                 25.0
# 2     2012.0             Drug                 36.0
# 3     2012.0             Drug                210.0
# 4     2012.0             Drug                117.0
#
#                                       NPROPNAME_2012       THER_CLASS_2012  \
# 0  .ALPHA.,TOCOPHEROL ACETATE, DL,, ASCORBIC ACID...  Nutritional Products
# 1  .ALPHA.,TOCOPHEROL ACETATE, DL,, ASCORBIC ACID...  Nutritional Products
# 2  .BETA.,CAROTENE, ASCORBIC ACID, CHOLECALCIFERO...  Nutritional Products
# 3  .BETA.,CAROTENE, ASCORBIC ACID, CHOLECALCIFERO...  Nutritional Products
# 4  .BETA.,CAROTENE, ASCORBIC ACID, CHOLECALCIFERO...  Nutritional Products
#
#                        PAYER_2012  UNIQUE_MEMBERS_2012  TOTAL_COST_2012  \
# 0                      Commercial                 99.0          2228.81
# 1  Minnesota Health Care Programs                 13.0           219.04
# 2                      Commercial                 26.0          6430.99
# 3                      Commercial                 92.0          3810.43
# 4  Minnesota Health Care Programs                 56.0          1082.49
#
#    COST_PER_USER_2012  COST_PER_SCRIPT_2012            ...             \
# 0           22.513232             16.268686            ...
# 1           16.849231              8.761600            ...
# 2          247.345769            178.638611            ...
# 3           41.417717             18.144905            ...
# 4           19.330179              9.252051            ...
#
#    PCT_SCRIPTS_0_18_2016  PCT_SCRIPTS_19_44_2016  PCT_SCRIPTS_45_64_2016  \
# 0                    NaN                     NaN                     NaN
# 1                    NaN                     NaN                     NaN
# 2                    NaN                     NaN                     NaN
# 3                    NaN                     NaN                     NaN
# 4                    NaN                     NaN                     NaN
#
#    PCT_SCRIPTS_65_PLUS_2016  PCT_SCRIPTS_FEMALE_2016  PCT_SCRIPTS_MALE_2016  \
# 0                       NaN                45.628998              54.371002
# 1                       NaN                43.280632              56.719368
# 2                       NaN                      NaN                    NaN
# 3                       NaN               100.000000               0.000000
# 4                       NaN                      NaN                    NaN
#
#    PCT_URBAN_CORE_2016  PCT_SUBURBAN_2016  PCT_MICROPOLITAN_2016  \
# 0             9.275053          29.424307              25.799574
# 1            11.758893          14.130435              23.023715
# 2                  NaN                NaN                    NaN
# 3                  NaN                NaN                    NaN
# 4                  NaN                NaN                    NaN
#
#    PCT_RURAL_SMALLTOWN_2016
# 0                 35.501066
# 1                 51.086957
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
# [5 rows x 96 columns]

# %%
# lost a significant portion of data with this merge (lost almost 40%)
# additionally, multiple NaN were introduced, but there is a business interpretation to this
# if the NaN is in 2012, then a new drug could have been created and then prescribed in 2016
# if the NaN is in 2016, then a drug is no longer being prescribed that was once available
prescription_merged.shape
# Out:
# (4971, 96)

# %% [markdown]
# Upon inspection, it is possible to join the two prescription files, but it will take a lot of work. For example in the 'NPROPNAME' an item has been listed two different ways: CALCIUM PANTOTHEN and CALCIUM P. I believe these are the same but will need outsider information to confirm. Until then these tables will not be joined.
#
# Confirmed this fact on my own using https://www.drugbank.ca/salts/DBSALT000034 and https://www.drugs.com/international/calcium-p.html
#
# Would love if someone else could confirm

# %%
# create new percent change columns filled with zeros and check
prescription_merged['PCT_CHANGE_COST_PER_SCRIPT_RANK'] = (prescription_merged['COST_PER_SCRIPT_RANK_2016'] - prescription_merged['COST_PER_SCRIPT_RANK_2012'] ) / prescription_merged['COST_PER_SCRIPT_RANK_2012'] * 100
prescription_merged['PCT_CHANGE_COST_PER_SCRIPT'] = (prescription_merged['COST_PER_SCRIPT_2016'] - prescription_merged['COST_PER_SCRIPT_2012'] ) / prescription_merged['COST_PER_SCRIPT_2012'] * 100
prescription_merged.head()
# Out:
#    YEAR_2012 RECORD_TYPE_2012  NUMBER_SCRIPTS_2012  \
# 0     2012.0             Drug                137.0
# 1     2012.0             Drug                 25.0
# 2     2012.0             Drug                 36.0
# 3     2012.0             Drug                210.0
# 4     2012.0             Drug                117.0
#
#                                       NPROPNAME_2012       THER_CLASS_2012  \
# 0  .ALPHA.,TOCOPHEROL ACETATE, DL,, ASCORBIC ACID...  Nutritional Products
# 1  .ALPHA.,TOCOPHEROL ACETATE, DL,, ASCORBIC ACID...  Nutritional Products
# 2  .BETA.,CAROTENE, ASCORBIC ACID, CHOLECALCIFERO...  Nutritional Products
# 3  .BETA.,CAROTENE, ASCORBIC ACID, CHOLECALCIFERO...  Nutritional Products
# 4  .BETA.,CAROTENE, ASCORBIC ACID, CHOLECALCIFERO...  Nutritional Products
#
#                        PAYER_2012  UNIQUE_MEMBERS_2012  TOTAL_COST_2012  \
# 0                      Commercial                 99.0          2228.81
# 1  Minnesota Health Care Programs                 13.0           219.04
# 2                      Commercial                 26.0          6430.99
# 3                      Commercial                 92.0          3810.43
# 4  Minnesota Health Care Programs                 56.0          1082.49
#
#    COST_PER_USER_2012  COST_PER_SCRIPT_2012             ...              \
# 0           22.513232             16.268686             ...
# 1           16.849231              8.761600             ...
# 2          247.345769            178.638611             ...
# 3           41.417717             18.144905             ...
# 4           19.330179              9.252051             ...
#
#    PCT_SCRIPTS_45_64_2016  PCT_SCRIPTS_65_PLUS_2016  PCT_SCRIPTS_FEMALE_2016  \
# 0                     NaN                       NaN                45.628998
# 1                     NaN                       NaN                43.280632
# 2                     NaN                       NaN                      NaN
# 3                     NaN                       NaN               100.000000
# 4                     NaN                       NaN                      NaN
#
#    PCT_SCRIPTS_MALE_2016  PCT_URBAN_CORE_2016  PCT_SUBURBAN_2016  \
# 0              54.371002             9.275053          29.424307
# 1              56.719368            11.758893          14.130435
# 2                    NaN                  NaN                NaN
# 3               0.000000                  NaN                NaN
# 4                    NaN                  NaN                NaN
#
#    PCT_MICROPOLITAN_2016  PCT_RURAL_SMALLTOWN_2016  \
# 0              25.799574                 35.501066
# 1              23.023715                 51.086957
# 2                    NaN                       NaN
# 3                    NaN                       NaN
# 4                    NaN                       NaN
#
#    PCT_CHANGE_COST_PER_SCRIPT_RANK  PCT_CHANGE_COST_PER_SCRIPT
# 0                         0.805802                  -21.689198
# 1                       -27.502176                  183.966173
# 2                              NaN                         NaN
# 3                       -18.600823                   94.776976
# 4                        -3.805310                   13.946508
#
# [5 rows x 98 columns]

# %%
# divide the drug file into their two years
drug_2012 = drug.loc[drug['YEAR'] == 2012]
drug_2012 = drug_2012.add_suffix('_2012')
drug_2016 = drug.loc[drug['YEAR'] == 2016]
drug_2016 = drug_2016.add_suffix('_2016')

# %%
# join drug file on ['NDC9','PRODUCT_NDC']
drug_merged = drug_2012.merge(drug_2016, how = "outer", left_on = ['NDC9_2012','PRODUCT_NDC_2012', 'RECORD_TYPE_2012','NPROPNAME_2012', 'THER_CLASS_2012','PAYER_2012'],
                                             right_on = ['NDC9_2016','PRODUCT_NDC_2016', 'RECORD_TYPE_2016','NPROPNAME_2016', 'THER_CLASS_2016','PAYER_2016'])
drug_merged.head()
# Out:
#    YEAR_2012 RECORD_TYPE_2012  NUMBER_SCRIPTS_2012    NDC9_2012  \
# 0     2012.0              NDC                 61.0  449461023.0
# 1     2012.0              NDC                 52.0  449461024.0
# 2     2012.0              NDC                 24.0  449461025.0
# 3     2012.0              NDC                 25.0  449461024.0
# 4     2012.0              NDC               5608.0  602580150.0
#
#   PRODUCT_NDC_2012  LAUNCH_YEAR_2012  \
# 0       44946-1023            2011.0
# 1       44946-1024            2011.0
# 2       44946-1025            2011.0
# 3       44946-1024            2011.0
# 4        60258-150            1999.0
#
#                                       NPROPNAME_2012  \
# 0  .ALPHA.,TOCOPHEROL ACETATE, DL,, ASCORBIC ACID...
# 1  .ALPHA.,TOCOPHEROL ACETATE, DL,, ASCORBIC ACID...
# 2  .ALPHA.,TOCOPHEROL ACETATE, DL,, ASCORBIC ACID...
# 3  .ALPHA.,TOCOPHEROL ACETATE, DL,, ASCORBIC ACID...
# 4     1.1% SODIUM FLUORIDE PRESCRIPTION DENTAL CREAM
#
#                 PROPNAME_2012 GENERIC_DRUG_IND_CODE_2012  \
# 0  MULTIVITAMIN WITH FLUORIDE                    Generic
# 1  MULTIVITAMIN WITH FLUORIDE                    Generic
# 2  MULTIVITAMIN WITH FLUORIDE                    Generic
# 3  MULTIVITAMIN WITH FLUORIDE                    Generic
# 4                SF 5000 PLUS                    Generic
#
#         THER_CLASS_2012  ... INSURER_PAID_STDDEV_2016 INSURER_PAID_SUM_2016  \
# 0  Nutritional Products  ...                 7.415849               1821.38
# 1  Nutritional Products  ...                 6.659666               1349.89
# 2  Nutritional Products  ...                 6.209248                637.60
# 3  Nutritional Products  ...                95.787149              16022.55
# 4      Topical Products  ...                 3.377492               7683.29
#
#   MEMBER_PAID_MEDIAN_2016 MEMBER_PAID_MEAN_2016 MEMBER_PAID_STDDEV_2016  \
# 0                    7.86              8.464293                7.962693
# 1                    6.49              8.555174                8.167800
# 2                    6.76              9.411751                8.017378
# 3                    0.00              0.331366                1.063510
# 4                    5.89              6.584231                5.117847
#
#    MEMBER_PAID_SUM_2016  TOTAL_PAID_MEDIAN_2016  TOTAL_PAID_MEAN_2016  \
# 0               3529.61                    9.60             12.834005
# 1               2942.98                   10.31             12.481977
# 2               1665.88                   10.51             13.020734
# 3                157.73                    5.44             34.028298
# 4              29721.22                    6.29              8.293062
#
#    TOTAL_PAID_STDDEV_2016  TOTAL_PAID_SUM_2016
# 0                7.793507              5351.78
# 1                7.485317              4293.80
# 2                7.592045              2304.67
# 3               95.683146             16197.47
# 4                4.670203             37434.88
#
# [5 rows x 80 columns]

# %%
# lost a significant portion of data with this merge (lost almost 25%)
# additionally, multiple NaN were introduced, but there is a business interpretation to this
# if the NaN is in 2012, then a new drug could have been created and then prescribed in 2016
# if the NaN is in 2016, then a drug is no longer being prescribed that was once available
drug_merged.shape
# Out:
# (32964, 80)

# %% [markdown]
# ## Step 5 - Convert to lists where applicable

# %%
# NPROPNAME in drug and prescription
prescription_merged['NPROPNAMES_2012'] = prescription_merged['NPROPNAME_2012'].str.split(",")
drug_merged['NPROPNAMES_2012'] = drug_merged['NPROPNAME_2012'].str.split(",")

prescription_merged['NPROPNAMES_2016'] = prescription_merged['NPROPNAME_2016'].str.split(",")
drug_merged['NPROPNAMES_2016'] = drug_merged['NPROPNAME_2016'].str.split(",")

# DOSAGE_FORM in drug
drug_merged['DOSAGE_FORMS_2012'] = drug_merged['DOSAGE_FORM_2012'].str.split(",")

drug_merged['DOSAGE_FORMS_2016'] = drug_merged['DOSAGE_FORM_2016'].str.split(",")

# ACTIVE_STRENGTH in drug
drug_merged['ACTIVE_STRENGTHS_2012'] = drug_merged['ACTIVE_STRENGTH_2012'].str.split(";")

drug_merged['ACTIVE_STRENGTHS_2016'] = drug_merged['ACTIVE_STRENGTH_2016'].str.split(";")

# ACTIVE_STRENGTH_UNIT in drug
drug_merged['ACTIVE_STRENGTH_UNITS_2012'] = drug_merged['ACTIVE_STRENGTH_UNIT_2012'].str.split(";")
drug_merged['ACTIVE_STRENGTH_UNITS_2016'] = drug_merged['ACTIVE_STRENGTH_UNIT_2016'].str.split(";")

# drop original columns
prescription_merged.drop(['NPROPNAME_2012', 'NPROPNAME_2016'], axis = 1)
drug_merged.drop(['NPROPNAME_2012', 'NPROPNAME_2016', 'DOSAGE_FORM_2012', 'DOSAGE_FORM_2016', 
                 'ACTIVE_STRENGTH_2012', 'ACTIVE_STRENGTH_2016', 'ACTIVE_STRENGTH_UNIT_2012',
                 'ACTIVE_STRENGTH_UNIT_2016'], axis = 1)
# Out:
#        YEAR_2012 RECORD_TYPE_2012  NUMBER_SCRIPTS_2012    NDC9_2012  \
# 0         2012.0              NDC                 61.0  449461023.0
# 1         2012.0              NDC                 52.0  449461024.0
# 2         2012.0              NDC                 24.0  449461025.0
# 3         2012.0              NDC                 25.0  449461024.0
# 4         2012.0              NDC               5608.0  602580150.0
# 5         2012.0              NDC               3309.0  602580150.0
# 6         2012.0              NDC               2861.0  602580150.0
# 7         2012.0              NDC                179.0    3784105.0
# 8         2012.0              NDC                282.0  497020221.0
# 9         2012.0              NDC                142.0    3784105.0
# 10        2012.0              NDC                293.0  497020221.0
# 11        2012.0              NDC                181.0    3784105.0
# 12        2012.0              NDC                249.0  497020221.0
# 13        2012.0              NDC               2085.0  497020206.0
# 14        2012.0              NDC               1611.0  497020206.0
# 15        2012.0              NDC               1725.0  497020206.0
# 16        2012.0              NDC                248.0  497020217.0
# 17        2012.0              NDC                152.0  497020217.0
# 18        2012.0              NDC                190.0  497020217.0
# 19        2012.0              NDC                408.0  578940150.0
# 20        2012.0              NDC                826.0  578940150.0
# 21        2012.0              NDC               1446.0    4563330.0
# 22        2012.0              NDC               1026.0    4563330.0
# 23        2012.0              NDC               1452.0    4563330.0
# 24        2012.0              NDC                 47.0     540141.0
# 25        2012.0              NDC                116.0    1151150.0
# 26        2012.0              NDC                 56.0    1151151.0
# 27        2012.0              NDC                122.0    3782820.0
# 28        2012.0              NDC                 40.0    3782821.0
# 29        2012.0              NDC                188.0  162520523.0
# ...          ...              ...                  ...          ...
# 32934        NaN              NaN                  NaN          NaN
# 32935        NaN              NaN                  NaN          NaN
# 32936        NaN              NaN                  NaN          NaN
# 32937        NaN              NaN                  NaN          NaN
# 32938        NaN              NaN                  NaN          NaN
# 32939        NaN              NaN                  NaN          NaN
# 32940        NaN              NaN                  NaN          NaN
# 32941        NaN              NaN                  NaN          NaN
# 32942        NaN              NaN                  NaN          NaN
# 32943        NaN              NaN                  NaN          NaN
# 32944        NaN              NaN                  NaN          NaN
# 32945        NaN              NaN                  NaN          NaN
# 32946        NaN              NaN                  NaN          NaN
# 32947        NaN              NaN                  NaN          NaN
# 32948        NaN              NaN                  NaN          NaN
# 32949        NaN              NaN                  NaN          NaN
# 32950        NaN              NaN                  NaN          NaN
# 32951        NaN              NaN                  NaN          NaN
# 32952        NaN              NaN                  NaN          NaN
# 32953        NaN              NaN                  NaN          NaN
# 32954        NaN              NaN                  NaN          NaN
# 32955        NaN              NaN                  NaN          NaN
# 32956        NaN              NaN                  NaN          NaN
# 32957        NaN              NaN                  NaN          NaN
# 32958        NaN              NaN                  NaN          NaN
# 32959        NaN              NaN                  NaN          NaN
# 32960        NaN              NaN                  NaN          NaN
# 32961        NaN              NaN                  NaN          NaN
# 32962        NaN              NaN                  NaN          NaN
# 32963        NaN              NaN                  NaN          NaN
#
#       PRODUCT_NDC_2012  LAUNCH_YEAR_2012               PROPNAME_2012  \
# 0           44946-1023            2011.0  MULTIVITAMIN WITH FLUORIDE
# 1           44946-1024            2011.0  MULTIVITAMIN WITH FLUORIDE
# 2           44946-1025            2011.0  MULTIVITAMIN WITH FLUORIDE
# 3           44946-1024            2011.0  MULTIVITAMIN WITH FLUORIDE
# 4            60258-150            1999.0                SF 5000 PLUS
# 5            60258-150            1999.0                SF 5000 PLUS
# 6            60258-150            1999.0                SF 5000 PLUS
# 7            0378-4105            2012.0            ABACAVIR SULFATE
# 8            49702-221            1998.0                      ZIAGEN
# 9            0378-4105            2012.0            ABACAVIR SULFATE
# 10           49702-221            1998.0                      ZIAGEN
# 11           0378-4105            2012.0            ABACAVIR SULFATE
# 12           49702-221            1998.0                      ZIAGEN
# 13           49702-206            2010.0                     EPZICOM
# 14           49702-206            2010.0                     EPZICOM
# 15           49702-206            2010.0                     EPZICOM
# 16           49702-217            2010.0                    TRIZIVIR
# 17           49702-217            2010.0                    TRIZIVIR
# 18           49702-217            2010.0                    TRIZIVIR
# 19           57894-150            2011.0                      ZYTIGA
# 20           57894-150            2011.0                      ZYTIGA
# 21           0456-3330            2005.0                     CAMPRAL
# 22           0456-3330            2005.0                     CAMPRAL
# 23           0456-3330            2005.0                     CAMPRAL
# 24           0054-0141            2008.0                    ACARBOSE
# 25           0115-1150            2009.0                    ACARBOSE
# 26           0115-1151            2009.0                    ACARBOSE
# 27           0378-2820            2011.0                    ACARBOSE
# 28           0378-2821            2011.0                    ACARBOSE
# 29           16252-523            2008.0                    ACARBOSE
# ...                ...               ...                         ...
# 32934              NaN               NaN                         NaN
# 32935              NaN               NaN                         NaN
# 32936              NaN               NaN                         NaN
# 32937              NaN               NaN                         NaN
# 32938              NaN               NaN                         NaN
# 32939              NaN               NaN                         NaN
# 32940              NaN               NaN                         NaN
# 32941              NaN               NaN                         NaN
# 32942              NaN               NaN                         NaN
# 32943              NaN               NaN                         NaN
# 32944              NaN               NaN                         NaN
# 32945              NaN               NaN                         NaN
# 32946              NaN               NaN                         NaN
# 32947              NaN               NaN                         NaN
# 32948              NaN               NaN                         NaN
# 32949              NaN               NaN                         NaN
# 32950              NaN               NaN                         NaN
# 32951              NaN               NaN                         NaN
# 32952              NaN               NaN                         NaN
# 32953              NaN               NaN                         NaN
# 32954              NaN               NaN                         NaN
# 32955              NaN               NaN                         NaN
# 32956              NaN               NaN                         NaN
# 32957              NaN               NaN                         NaN
# 32958              NaN               NaN                         NaN
# 32959              NaN               NaN                         NaN
# 32960              NaN               NaN                         NaN
# 32961              NaN               NaN                         NaN
# 32962              NaN               NaN                         NaN
# 32963              NaN               NaN                         NaN
#
#       GENERIC_DRUG_IND_CODE_2012                    THER_CLASS_2012  \
# 0                        Generic               Nutritional Products
# 1                        Generic               Nutritional Products
# 2                        Generic               Nutritional Products
# 3                        Generic               Nutritional Products
# 4                        Generic                   Topical Products
# 5                        Generic                   Topical Products
# 6                        Generic                   Topical Products
# 7                        Generic              Anti-Infective Agents
# 8                          Brand              Anti-Infective Agents
# 9                        Generic              Anti-Infective Agents
# 10                         Brand              Anti-Infective Agents
# 11                       Generic              Anti-Infective Agents
# 12                         Brand              Anti-Infective Agents
# 13                         Brand              Anti-Infective Agents
# 14                         Brand              Anti-Infective Agents
# 15                         Brand              Anti-Infective Agents
# 16                         Brand              Anti-Infective Agents
# 17                         Brand              Anti-Infective Agents
# 18                         Brand              Anti-Infective Agents
# 19                         Brand              Antineoplastic Agents
# 20                         Brand              Antineoplastic Agents
# 21                         Brand  Misc Psychotherapeutic/Neurologic
# 22                         Brand  Misc Psychotherapeutic/Neurologic
# 23                         Brand  Misc Psychotherapeutic/Neurologic
# 24                       Generic      Endocrine and Metabolic Drugs
# 25                       Generic      Endocrine and Metabolic Drugs
# 26                       Generic      Endocrine and Metabolic Drugs
# 27                       Generic      Endocrine and Metabolic Drugs
# 28                       Generic      Endocrine and Metabolic Drugs
# 29                       Generic      Endocrine and Metabolic Drugs
# ...                          ...                                ...
# 32934                        NaN                                NaN
# 32935                        NaN                                NaN
# 32936                        NaN                                NaN
# 32937                        NaN                                NaN
# 32938                        NaN                                NaN
# 32939                        NaN                                NaN
# 32940                        NaN                                NaN
# 32941                        NaN                                NaN
# 32942                        NaN                                NaN
# 32943                        NaN                                NaN
# 32944                        NaN                                NaN
# 32945                        NaN                                NaN
# 32946                        NaN                                NaN
# 32947                        NaN                                NaN
# 32948                        NaN                                NaN
# 32949                        NaN                                NaN
# 32950                        NaN                                NaN
# 32951                        NaN                                NaN
# 32952                        NaN                                NaN
# 32953                        NaN                                NaN
# 32954                        NaN                                NaN
# 32955                        NaN                                NaN
# 32956                        NaN                                NaN
# 32957                        NaN                                NaN
# 32958                        NaN                                NaN
# 32959                        NaN                                NaN
# 32960                        NaN                                NaN
# 32961                        NaN                                NaN
# 32962                        NaN                                NaN
# 32963                        NaN                                NaN
#
#                      LABELERNAME_2012  ... TOTAL_PAID_STDDEV_2016  \
# 0                            SANCILIO  ...               7.793507
# 1                            SANCILIO  ...               7.485317
# 2                            SANCILIO  ...               7.592045
# 3                            SANCILIO  ...              95.683146
# 4              CYPRESS PHARMACEUTICAL  ...               4.670203
# 5              CYPRESS PHARMACEUTICAL  ...               5.415955
# 6              CYPRESS PHARMACEUTICAL  ...               2.022142
# 7                               MYLAN  ...                    NaN
# 8             VIIV HEALTHCARE COMPANY  ...                    NaN
# 9                               MYLAN  ...                    NaN
# 10            VIIV HEALTHCARE COMPANY  ...                    NaN
# 11                              MYLAN  ...                    NaN
# 12            VIIV HEALTHCARE COMPANY  ...                    NaN
# 13            VIIV HEALTHCARE COMPANY  ...             763.489587
# 14            VIIV HEALTHCARE COMPANY  ...             568.912165
# 15            VIIV HEALTHCARE COMPANY  ...             313.621531
# 16            VIIV HEALTHCARE COMPANY  ...                    NaN
# 17            VIIV HEALTHCARE COMPANY  ...                    NaN
# 18            VIIV HEALTHCARE COMPANY  ...                    NaN
# 19             CENTOCOR ORTHO BIOTECH  ...            2904.218305
# 20             CENTOCOR ORTHO BIOTECH  ...            2690.902476
# 21          FOREST LABORATORIES, INC.  ...                    NaN
# 22          FOREST LABORATORIES, INC.  ...                    NaN
# 23          FOREST LABORATORIES, INC.  ...                    NaN
# 24     BOEHRINGER INGELHEIM ROXANE, I  ...              51.275288
# 25             GLOBAL PHARMACEUTICALS  ...                    NaN
# 26             GLOBAL PHARMACEUTICALS  ...                    NaN
# 27        MYLAN PHARMACEUTICALS, INC.  ...              49.690359
# 28        MYLAN PHARMACEUTICALS, INC.  ...                    NaN
# 29                     ACTAVIS PHARMA  ...              51.129720
# ...                               ...  ...                    ...
# 32934                             NaN  ...               2.869999
# 32935                             NaN  ...              20.752062
# 32936                             NaN  ...               1.979914
# 32937                             NaN  ...              61.629054
# 32938                             NaN  ...              41.869130
# 32939                             NaN  ...              21.208099
# 32940                             NaN  ...              57.902743
# 32941                             NaN  ...              48.475640
# 32942                             NaN  ...               3.399803
# 32943                             NaN  ...              31.924821
# 32944                             NaN  ...              21.686569
# 32945                             NaN  ...              21.515102
# 32946                             NaN  ...              28.203271
# 32947                             NaN  ...            2096.214518
# 32948                             NaN  ...              24.510055
# 32949                             NaN  ...              40.877602
# 32950                             NaN  ...              24.728183
# 32951                             NaN  ...              15.800319
# 32952                             NaN  ...            2355.511164
# 32953                             NaN  ...               7.946994
# 32954                             NaN  ...               9.091636
# 32955                             NaN  ...              25.256963
# 32956                             NaN  ...              43.246544
# 32957                             NaN  ...              10.074123
# 32958                             NaN  ...              15.319968
# 32959                             NaN  ...             829.177385
# 32960                             NaN  ...              17.937992
# 32961                             NaN  ...               9.012574
# 32962                             NaN  ...              12.310994
# 32963                             NaN  ...              20.625050
#
#        TOTAL_PAID_SUM_2016                                    NPROPNAMES_2012  \
# 0                  5351.78  [.ALPHA., TOCOPHEROL ACETATE,  DL, ,  ASCORBIC...
# 1                  4293.80  [.ALPHA., TOCOPHEROL ACETATE,  DL, ,  ASCORBIC...
# 2                  2304.67  [.ALPHA., TOCOPHEROL ACETATE,  DL, ,  ASCORBIC...
# 3                 16197.47  [.ALPHA., TOCOPHEROL ACETATE,  DL, ,  ASCORBIC...
# 4                 37434.88   [1.1% SODIUM FLUORIDE PRESCRIPTION DENTAL CREAM]
# 5                 18874.50   [1.1% SODIUM FLUORIDE PRESCRIPTION DENTAL CREAM]
# 6                 32295.18   [1.1% SODIUM FLUORIDE PRESCRIPTION DENTAL CREAM]
# 7                      NaN                                 [ABACAVIR SULFATE]
# 8                      NaN                                 [ABACAVIR SULFATE]
# 9                      NaN                                 [ABACAVIR SULFATE]
# 10                     NaN                                 [ABACAVIR SULFATE]
# 11                     NaN                                 [ABACAVIR SULFATE]
# 12                     NaN                                 [ABACAVIR SULFATE]
# 13               786746.44                    [ABACAVIR SULFATE,  LAMIVUDINE]
# 14              1374508.15                    [ABACAVIR SULFATE,  LAMIVUDINE]
# 15              1318628.93                    [ABACAVIR SULFATE,  LAMIVUDINE]
# 16                     NaN       [ABACAVIR SULFATE,  LAMIVUDINE,  ZIDOVUDINE]
# 17                     NaN       [ABACAVIR SULFATE,  LAMIVUDINE,  ZIDOVUDINE]
# 18                     NaN       [ABACAVIR SULFATE,  LAMIVUDINE,  ZIDOVUDINE]
# 19              5237918.36                              [ABIRATERONE ACETATE]
# 20             20092087.53                              [ABIRATERONE ACETATE]
# 21                     NaN                              [ACAMPROSATE CALCIUM]
# 22                     NaN                              [ACAMPROSATE CALCIUM]
# 23                     NaN                              [ACAMPROSATE CALCIUM]
# 24                 2135.26                                         [ACARBOSE]
# 25                     NaN                                         [ACARBOSE]
# 26                     NaN                                         [ACARBOSE]
# 27                 1588.58                                         [ACARBOSE]
# 28                     NaN                                         [ACARBOSE]
# 29                 2569.49                                         [ACARBOSE]
# ...                    ...                                                ...
# 32934                44.94                                                NaN
# 32935               112.74                                                NaN
# 32936               199.70                                                NaN
# 32937             64757.52                                                NaN
# 32938            148265.22                                                NaN
# 32939               287.42                                                NaN
# 32940             29166.49                                                NaN
# 32941            100645.20                                                NaN
# 32942               223.15                                                NaN
# 32943             17903.34                                                NaN
# 32944             56409.32                                                NaN
# 32945              2044.81                                                NaN
# 32946              1122.45                                                NaN
# 32947            217211.40                                                NaN
# 32948              5394.62                                                NaN
# 32949             10463.68                                                NaN
# 32950              1426.51                                                NaN
# 32951               487.60                                                NaN
# 32952            442662.12                                                NaN
# 32953               838.76                                                NaN
# 32954               884.53                                                NaN
# 32955              5170.32                                                NaN
# 32956             14668.35                                                NaN
# 32957               843.24                                                NaN
# 32958               743.03                                                NaN
# 32959            215638.70                                                NaN
# 32960              4818.73                                                NaN
# 32961               432.70                                                NaN
# 32962              2147.95                                                NaN
# 32963              9276.42                                                NaN
#
#                                          NPROPNAMES_2016  \
# 0      [.ALPHA., TOCOPHEROL ACETATE,  DL, ,  ASCORBIC...
# 1      [.ALPHA., TOCOPHEROL ACETATE,  DL, ,  ASCORBIC...
# 2      [.ALPHA., TOCOPHEROL ACETATE,  DL, ,  ASCORBIC...
# 3      [.ALPHA., TOCOPHEROL ACETATE,  DL, ,  ASCORBIC...
# 4       [1.1% SODIUM FLUORIDE PRESCRIPTION DENTAL CREAM]
# 5       [1.1% SODIUM FLUORIDE PRESCRIPTION DENTAL CREAM]
# 6       [1.1% SODIUM FLUORIDE PRESCRIPTION DENTAL CREAM]
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                       [ABACAVIR SULFATE,  LAMIVUDINE]
# 14                       [ABACAVIR SULFATE,  LAMIVUDINE]
# 15                       [ABACAVIR SULFATE,  LAMIVUDINE]
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                 [ABIRATERONE ACETATE]
# 20                                 [ABIRATERONE ACETATE]
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                            [ACARBOSE]
# 25                                                   NaN
# 26                                                   NaN
# 27                                            [ACARBOSE]
# 28                                                   NaN
# 29                                            [ACARBOSE]
# ...                                                  ...
# 32934                                [ZOLPIDEM TARTRATE]
# 32935                                [ZOLPIDEM TARTRATE]
# 32936                                [ZOLPIDEM TARTRATE]
# 32937                                [ZOLPIDEM TARTRATE]
# 32938                                [ZOLPIDEM TARTRATE]
# 32939                                [ZOLPIDEM TARTRATE]
# 32940                                [ZOLPIDEM TARTRATE]
# 32941                                [ZOLPIDEM TARTRATE]
# 32942                                [ZOLPIDEM TARTRATE]
# 32943                                [ZOLPIDEM TARTRATE]
# 32944                                [ZOLPIDEM TARTRATE]
# 32945                                       [ZONISAMIDE]
# 32946                                       [ZONISAMIDE]
# 32947                                       [ZONISAMIDE]
# 32948                                       [ZONISAMIDE]
# 32949                                       [ZONISAMIDE]
# 32950                                       [ZONISAMIDE]
# 32951                                       [ZONISAMIDE]
# 32952                                       [ZONISAMIDE]
# 32953                                       [ZONISAMIDE]
# 32954                                       [ZONISAMIDE]
# 32955                                       [ZONISAMIDE]
# 32956                                       [ZONISAMIDE]
# 32957                                       [ZONISAMIDE]
# 32958                                       [ZONISAMIDE]
# 32959                                       [ZONISAMIDE]
# 32960                                       [ZONISAMIDE]
# 32961                                       [ZONISAMIDE]
# 32962                                       [ZONISAMIDE]
# 32963                                       [ZONISAMIDE]
#
#                 DOSAGE_FORMS_2012            DOSAGE_FORMS_2016  \
# 0             [TABLET,  CHEWABLE]          [TABLET,  CHEWABLE]
# 1             [TABLET,  CHEWABLE]          [TABLET,  CHEWABLE]
# 2             [TABLET,  CHEWABLE]          [TABLET,  CHEWABLE]
# 3             [TABLET,  CHEWABLE]          [TABLET,  CHEWABLE]
# 4                         [CREAM]                      [CREAM]
# 5                         [CREAM]                      [CREAM]
# 6                         [CREAM]                      [CREAM]
# 7          [TABLET,  FILM COATED]                          NaN
# 8          [TABLET,  FILM COATED]                          NaN
# 9          [TABLET,  FILM COATED]                          NaN
# 10         [TABLET,  FILM COATED]                          NaN
# 11         [TABLET,  FILM COATED]                          NaN
# 12         [TABLET,  FILM COATED]                          NaN
# 13         [TABLET,  FILM COATED]       [TABLET,  FILM COATED]
# 14         [TABLET,  FILM COATED]       [TABLET,  FILM COATED]
# 15         [TABLET,  FILM COATED]       [TABLET,  FILM COATED]
# 16         [TABLET,  FILM COATED]                          NaN
# 17         [TABLET,  FILM COATED]                          NaN
# 18         [TABLET,  FILM COATED]                          NaN
# 19                       [TABLET]                     [TABLET]
# 20                       [TABLET]                     [TABLET]
# 21     [TABLET,  DELAYED RELEASE]                          NaN
# 22     [TABLET,  DELAYED RELEASE]                          NaN
# 23     [TABLET,  DELAYED RELEASE]                          NaN
# 24                       [TABLET]                     [TABLET]
# 25                       [TABLET]                          NaN
# 26                       [TABLET]                          NaN
# 27                       [TABLET]                     [TABLET]
# 28                       [TABLET]                          NaN
# 29                       [TABLET]                     [TABLET]
# ...                           ...                          ...
# 32934                         NaN                     [TABLET]
# 32935                         NaN       [TABLET,  FILM COATED]
# 32936                         NaN       [TABLET,  FILM COATED]
# 32937                         NaN  [TABLET,  EXTENDED RELEASE]
# 32938                         NaN  [TABLET,  EXTENDED RELEASE]
# 32939                         NaN                     [TABLET]
# 32940                         NaN  [TABLET,  EXTENDED RELEASE]
# 32941                         NaN  [TABLET,  EXTENDED RELEASE]
# 32942                         NaN       [TABLET,  FILM COATED]
# 32943                         NaN  [TABLET,  EXTENDED RELEASE]
# 32944                         NaN  [TABLET,  EXTENDED RELEASE]
# 32945                         NaN                    [CAPSULE]
# 32946                         NaN                    [CAPSULE]
# 32947                         NaN                    [CAPSULE]
# 32948                         NaN                    [CAPSULE]
# 32949                         NaN                    [CAPSULE]
# 32950                         NaN                    [CAPSULE]
# 32951                         NaN                    [CAPSULE]
# 32952                         NaN                    [CAPSULE]
# 32953                         NaN                    [CAPSULE]
# 32954                         NaN                    [CAPSULE]
# 32955                         NaN                    [CAPSULE]
# 32956                         NaN                    [CAPSULE]
# 32957                         NaN                    [CAPSULE]
# 32958                         NaN                    [CAPSULE]
# 32959                         NaN                    [CAPSULE]
# 32960                         NaN                    [CAPSULE]
# 32961                         NaN                    [CAPSULE]
# 32962                         NaN                    [CAPSULE]
# 32963                         NaN                    [CAPSULE]
#
#                                    ACTIVE_STRENGTHS_2012  \
# 0      [15,  60,  4.5,  .25,  .3,  13.5,  1.05,  1.2,...
# 1      [15,  60,  4.5,  .5,  .3,  13.5,  1.05,  1.2, ...
# 2      [15,  60,  4.5,  1,  .3,  13.5,  1.05,  1.2,  ...
# 3      [15,  60,  4.5,  .5,  .3,  13.5,  1.05,  1.2, ...
# 4                                                   [11]
# 5                                                   [11]
# 6                                                   [11]
# 7                                                  [300]
# 8                                                  [300]
# 9                                                  [300]
# 10                                                 [300]
# 11                                                 [300]
# 12                                                 [300]
# 13                                           [600,  300]
# 14                                           [600,  300]
# 15                                           [600,  300]
# 16                                     [300,  150,  300]
# 17                                     [300,  150,  300]
# 18                                     [300,  150,  300]
# 19                                                 [250]
# 20                                                 [250]
# 21                                                 [333]
# 22                                                 [333]
# 23                                                 [333]
# 24                                                  [50]
# 25                                                  [25]
# 26                                                  [50]
# 27                                                  [25]
# 28                                                  [50]
# 29                                                  [25]
# ...                                                  ...
# 32934                                                NaN
# 32935                                                NaN
# 32936                                                NaN
# 32937                                                NaN
# 32938                                                NaN
# 32939                                                NaN
# 32940                                                NaN
# 32941                                                NaN
# 32942                                                NaN
# 32943                                                NaN
# 32944                                                NaN
# 32945                                                NaN
# 32946                                                NaN
# 32947                                                NaN
# 32948                                                NaN
# 32949                                                NaN
# 32950                                                NaN
# 32951                                                NaN
# 32952                                                NaN
# 32953                                                NaN
# 32954                                                NaN
# 32955                                                NaN
# 32956                                                NaN
# 32957                                                NaN
# 32958                                                NaN
# 32959                                                NaN
# 32960                                                NaN
# 32961                                                NaN
# 32962                                                NaN
# 32963                                                NaN
#
#                                    ACTIVE_STRENGTHS_2016  \
# 0      [15,  60,  4.5,  .25,  .3,  13.5,  1.05,  1.2,...
# 1      [15,  60,  4.5,  .5,  .3,  13.5,  1.05,  1.2, ...
# 2      [15,  60,  4.5,  1,  .3,  13.5,  1.05,  1.2,  ...
# 3      [15,  60,  4.5,  .5,  .3,  13.5,  1.05,  1.2, ...
# 4                                                   [11]
# 5                                                   [11]
# 6                                                   [11]
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                           [600,  300]
# 14                                           [600,  300]
# 15                                           [600,  300]
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                 [250]
# 20                                                 [250]
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                  [50]
# 25                                                   NaN
# 26                                                   NaN
# 27                                                  [25]
# 28                                                   NaN
# 29                                                  [25]
# ...                                                  ...
# 32934                                                [5]
# 32935                                               [10]
# 32936                                               [10]
# 32937                                             [6.25]
# 32938                                             [12.5]
# 32939                                                [5]
# 32940                                             [6.25]
# 32941                                             [12.5]
# 32942                                                [5]
# 32943                                             [6.25]
# 32944                                             [12.5]
# 32945                                               [25]
# 32946                                               [50]
# 32947                                              [100]
# 32948                                               [50]
# 32949                                              [100]
# 32950                                               [25]
# 32951                                               [50]
# 32952                                              [100]
# 32953                                               [25]
# 32954                                               [50]
# 32955                                              [100]
# 32956                                              [100]
# 32957                                               [25]
# 32958                                               [50]
# 32959                                              [100]
# 32960                                               [50]
# 32961                                               [25]
# 32962                                              [100]
# 32963                                              [100]
#
#                               ACTIVE_STRENGTH_UNITS_2012  \
# 0      [[IU]/1,  MG/1,  UG/1,  MG/1,  MG/1,  MG/1,  M...
# 1      [[IU]/1,  MG/1,  UG/1,  MG/1,  MG/1,  MG/1,  M...
# 2      [[IU]/1,  MG/1,  UG/1,  MG/1,  MG/1,  MG/1,  M...
# 3      [[IU]/1,  MG/1,  UG/1,  MG/1,  MG/1,  MG/1,  M...
# 4                                                 [MG/G]
# 5                                                 [MG/G]
# 6                                                 [MG/G]
# 7                                                 [MG/1]
# 8                                                 [MG/1]
# 9                                                 [MG/1]
# 10                                                [MG/1]
# 11                                                [MG/1]
# 12                                                [MG/1]
# 13                                         [MG/1,  MG/1]
# 14                                         [MG/1,  MG/1]
# 15                                         [MG/1,  MG/1]
# 16                                  [MG/1,  MG/1,  MG/1]
# 17                                  [MG/1,  MG/1,  MG/1]
# 18                                  [MG/1,  MG/1,  MG/1]
# 19                                                [MG/1]
# 20                                                [MG/1]
# 21                                                [MG/1]
# 22                                                [MG/1]
# 23                                                [MG/1]
# 24                                                [MG/1]
# 25                                                [MG/1]
# 26                                                [MG/1]
# 27                                                [MG/1]
# 28                                                [MG/1]
# 29                                                [MG/1]
# ...                                                  ...
# 32934                                                NaN
# 32935                                                NaN
# 32936                                                NaN
# 32937                                                NaN
# 32938                                                NaN
# 32939                                                NaN
# 32940                                                NaN
# 32941                                                NaN
# 32942                                                NaN
# 32943                                                NaN
# 32944                                                NaN
# 32945                                                NaN
# 32946                                                NaN
# 32947                                                NaN
# 32948                                                NaN
# 32949                                                NaN
# 32950                                                NaN
# 32951                                                NaN
# 32952                                                NaN
# 32953                                                NaN
# 32954                                                NaN
# 32955                                                NaN
# 32956                                                NaN
# 32957                                                NaN
# 32958                                                NaN
# 32959                                                NaN
# 32960                                                NaN
# 32961                                                NaN
# 32962                                                NaN
# 32963                                                NaN
#
#                               ACTIVE_STRENGTH_UNITS_2016
# 0      [[IU]/1,  MG/1,  UG/1,  MG/1,  MG/1,  MG/1,  M...
# 1      [[IU]/1,  MG/1,  UG/1,  MG/1,  MG/1,  MG/1,  M...
# 2      [[IU]/1,  MG/1,  UG/1,  MG/1,  MG/1,  MG/1,  M...
# 3      [[IU]/1,  MG/1,  UG/1,  MG/1,  MG/1,  MG/1,  M...
# 4                                                 [MG/G]
# 5                                                 [MG/G]
# 6                                                 [MG/G]
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                         [MG/1,  MG/1]
# 14                                         [MG/1,  MG/1]
# 15                                         [MG/1,  MG/1]
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                [MG/1]
# 20                                                [MG/1]
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                [MG/1]
# 25                                                   NaN
# 26                                                   NaN
# 27                                                [MG/1]
# 28                                                   NaN
# 29                                                [MG/1]
# ...                                                  ...
# 32934                                             [MG/1]
# 32935                                             [MG/1]
# 32936                                             [MG/1]
# 32937                                             [MG/1]
# 32938                                             [MG/1]
# 32939                                             [MG/1]
# 32940                                             [MG/1]
# 32941                                             [MG/1]
# 32942                                             [MG/1]
# 32943                                             [MG/1]
# 32944                                             [MG/1]
# 32945                                             [MG/1]
# 32946                                             [MG/1]
# 32947                                             [MG/1]
# 32948                                             [MG/1]
# 32949                                             [MG/1]
# 32950                                             [MG/1]
# 32951                                             [MG/1]
# 32952                                             [MG/1]
# 32953                                             [MG/1]
# 32954                                             [MG/1]
# 32955                                             [MG/1]
# 32956                                             [MG/1]
# 32957                                             [MG/1]
# 32958                                             [MG/1]
# 32959                                             [MG/1]
# 32960                                             [MG/1]
# 32961                                             [MG/1]
# 32962                                             [MG/1]
# 32963                                             [MG/1]
#
# [32964 rows x 80 columns]

# %% [markdown]
# ## Step 6 - Write cleaned data to new files

# %%
drug_merged.to_excel("C:/Users/LMoor/Downloads/Drug_Clean_v2.xlsx")
prescription_merged.to_excel("C:/Users/LMoor/Downloads/Prescription_Clean_v2.xlsx")
